# %%
from rag_pipeline import ask_rag
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from rag_pipeline import ask_rag
#
# ImportError: cannot import name 'ask_rag' from 'rag_pipeline' (c:\Users\bilal\Desktop\AnalyticsVidhya_Assessment\rag_pipeline.py)

# %%
result = ask_rag(
    "What is a Python decorator?"
)

print(result["answer"])
